// %% [markdown]
// ## GAN 资料
//
// - Ma J., 2025. Causal Inference with Large Language Model: A SurveyJing Ma, [-PDF-](https://aclanthology.org/2025.findings-naacl.327.pdf)
// - Borisov, V., Leemann, T., Seßler, K., Haug, J., Pawelczyk, M., & Kasneci, G. (2024). Deep Neural Networks and Tabular Data: A Survey. IEEE Transactions on Neural Networks and Learning Systems, 35(6), 7499–7519. [Link](https://doi.org/10.1109/TNNLS.2022.3229161), [PDF](http://sci-hub.ren/10.1109/TNNLS.2022.3229161), [Google](<https://scholar.google.com/scholar?q=Deep Neural Networks and Tabular Data: A Survey>).
//   - The key results of the paper include an empirical comparison of traditional machine learning methods with eleven deep learning approaches on real-world tabular data sets, indicating that gradient-boosted tree ensembles still mostly outperform deep learning models on supervised learning tasks. The paper also provides a comprehensive overview of deep learning methods for tabular data, categorizing them into data transformations, specialized architectures, and regularization models. Additionally, the paper discusses deep learning approaches for generating tabular data and strategies for explaining deep models on tabular data.
// - Jiao, L., Wang, Y., Liu, X., Li, L., Liu, F., Ma, W., Guo, Y., Chen, P., Yang, S., & Hou, B. (2024). Causal Inference Meets Deep Learning: A Comprehensive Survey. Research, 7. [Link](https://doi.org/10.34133/research.0467), [PDF](https://pdfs.semanticscholar.org/03c8/0d8a4f1093011331164ece66d902cc29c455.pdf?_gl=1*188jpe*_gcl_au*NTg0Nzc3MzY5LjE3NTY3MzcyMTg.*_ga*MTYxNTEyMjU1My4xNzU2NzM3MjIw*_ga_H7P4ZT52H5*czE3NTY5MTM2MTUkbzMkZzAkdDE3NTY5MTM2MTckajU4JGwwJGgw), [Google](<https://scholar.google.com/scholar?q=Causal Inference Meets Deep Learning: A Comprehensive Survey>).
//
//
// ## 简介
//
// > Source: Demystifying Generative Adversarial Nets (GANs). [-Link-](https://www.datacamp.com/tutorial/generative-adversarial-networks)
//
// In this tutorial, you will learn what Generative Adversarial Networks (GANs) are without going into the details of the math. After, you will learn how to code a simple GAN which can create digits!
//
// Analogy
// -------
//
// The easiest way to understand what GANs are is through a simple analogy:
//
// Suppose there is a shop which buys certain kinds of wine from customers which they will later resell.
//
// ![analogy](https://media.datacamp.com/legacy/image/upload/f_auto,q_auto:best/v1524648806/gan_real_ylxk5f.jpg)
//
// However, there are nefarious customers who sell fake wine in order to get money. In this case, the shop owner has to be able to distinguish between the fake and authentic wines.
//
// ![analogy](https://media.datacamp.com/legacy/image/upload/f_auto,q_auto:best/v1524648806/gan_fake_mr7pd8.jpg)
//
// You can imagine that initially, the forger might make a lot of mistakes when trying to sell the fake wine and it will be easy for the shop owner to identify that the wine is not authentic. Because of these failures, the forger will keep on trying different techniques to simulate the authentic wines and some will eventually be successful. Now that the forger knows that certain techniques got past the shop owner's checks, he can start to further improve the fake wines based on those techniques.
//
// At the same time, the shop owner would probably get some feedback from other shop owners or wine experts that some of the wines that she has are not original. This means that the shop owner would have to improve how she determines whether a wine is fake or authentic. The goal of the forger is to create wines that are indistinguishable from the authentic ones, and the goal of the shop owner is to accurately tell if a wine is real or not.
//
// This back-and-forth competition is the main idea behind GANs.

// %% [markdown]
// ##

// %%
getiref 2104.10680 , m ar
// Out:
// Running D:\stata17/profile.do ...
// <style>div.jp-Notebook .datagrid-container {min-height: 448px; }</style>
//
// Wen, B., Colon, L. O., Subbalakshmi, K. P., & Chandramouli, R. (2021). Causal-T
// > GAN: Generating Tabular Data Using Causal Generative Adversarial Networks (Ve
// > rsion 1). arXiv.
//     Link (rep)    PDF    Google
//
// Wen, B., Colon, L. O., Subbalakshmi, K. P., & Chandramouli, R. (2021). Causal-T
// > GAN: Generating Tabular Data Using Causal Generative Adversarial Networks (Ve
// > rsion 1). arXiv. [Link](https://doi.org/10.48550/arXiv.2104.10680) (rep), [PD
// > F](https://arxiv.org/pdf/2104.10680.pdf), [Google](<https://scholar.google.co
// > m/scholar?q=Causal-TGAN: Generating Tabular Data Using Causal Generative Adve
// > rsarial Networks (Version 1)>).
//
// Tips: Text is on clipboard. Press 'Ctrl+V' to paste, ^-^

// %% [markdown]
// Wen, B., Colon, L. O., Subbalakshmi, K. P., & Chandramouli, R. (2021). Causal-TGAN: Generating Tabular Data Using Causal Generative Adversarial Networks (Version 1). arXiv. [Link](https://doi.org/10.48550/arXiv.2104.10680) (rep), [PDF](https://arxiv.org/pdf/2104.10680.pdf), [Google](<https://scholar.google.com/scholar?q=Causal-TGAN: Generating Tabular Data Using Causal Generative Adversarial Networks (Version 1)>).

// %% [markdown]
// ## Representation Learning for Tabular Data: A Comprehensive Survey

// %%
getiref     2504.16109    , m ar
// Out:
//
// Jiang, J.-P., Liu, S.-Y., Cai, H.-R., Zhou, Q., & Ye, H.-J. (2025). Representat
// > ion Learning for Tabular Data: A Comprehensive Survey (Version 1). arXiv.
//     Link (rep)    PDF    Google
//
// Jiang, J.-P., Liu, S.-Y., Cai, H.-R., Zhou, Q., & Ye, H.-J. (2025). Representat
// > ion Learning for Tabular Data: A Comprehensive Survey (Version 1). arXiv. [Li
// > nk](https://doi.org/10.48550/arXiv.2504.16109) (rep), [PDF](https://arxiv.org
// > /pdf/2504.16109.pdf), [Google](<https://scholar.google.com/scholar?q=Represen
// > tation Learning for Tabular Data: A Comprehensive Survey (Version 1)>).
//
// Tips: Text is on clipboard. Press 'Ctrl+V' to paste, ^-^

// %% [markdown]
// Jiang, J.-P., Liu, S.-Y., Cai, H.-R., Zhou, Q., & Ye, H.-J. (2025). Representation Learning for Tabular Data: A Comprehensive Survey (Version 1). arXiv. [Link](https://doi.org/10.48550/arXiv.2504.16109) (rep), [PDF](https://arxiv.org/pdf/2504.16109.pdf), [Google](<https://scholar.google.com/scholar?q=Representation Learning for Tabular Data: A Comprehensive Survey (Version 1)>). [github](https://github.com/LAMDA-Tabular/Tabular-Survey)
// - [github](https://github.com/LAMDA-Tabular/Tabular-Survey) 中提供了各类方法的文献和代码实现，方便研究人员进行参考和使用。
//
//
// ![20250904095106](https://fig-lianxh.oss-cn-shenzhen.aliyuncs.com/20250904095106.png)

// %% [markdown]
// ## 最优化问题
//
//
// ![20250914000442](https://fig-lianxh.oss-cn-shenzhen.aliyuncs.com/20250914000442.png)
//
// > Source: <https://www.cs.umd.edu/~tomg/project/stable_gans/>
